# %%
import pandas as pd

# %%
print "Aimee is great!"
# Out:
# Aimee is great!

# %% [markdown]
# # Josh is great too!

# %%
for i in range(1000):
    print "Josh is great!"
# Out:
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# Josh is great!
# ...
